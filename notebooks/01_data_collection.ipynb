# %%
print("Hello, PortfolioSense!")
# Out:
# Hello, PortfolioSense!

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

reliance = yf.download("RELIANCE.NS", start="2019-01-01", end="2026-06-18")
print(reliance.head())
print(reliance.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import yfinance as yf
#       3 reliance = yf.download("RELIANCE.NS", start="2019-01-01", end="2026-06-18")
#       4 print(reliance.head())
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
print("Hello, PortfolioSense!")
# Out:
# Hello, PortfolioSense!

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

reliance = yf.download("RELIANCE.NS", start="2019-01-01", end="2026-06-18")
print(reliance.head())
print(reliance.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open      Volume
# Ticker     RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.NS
# Date
# 2019-01-01  496.196381  498.985034  491.371654  498.077624     9746670
# 2019-01-02  489.733887  498.852220  487.343625  493.319235    15628818
# 2019-01-03  483.691925  493.363540  482.518940  490.220816    16288287
# 2019-01-04  486.303467  488.870779  478.535197  485.750186    18516544
# 2019-01-07  489.003540  495.067675  487.343638  489.999475    12060290
# (1844, 5)

# %%
tickers = ["RELIANCE.NS", "TCS.NS", "HDFCBANK.NS", "INFY.NS", 
           "ICICIBANK.NS", "HINDUNILVR.NS", "BHARTIARTL.NS", "TATAMOTORS.NS"]

data = yf.download(tickers, start="2019-01-01", end="2026-06-18")
print(data.head())
print(data.shape)
print(data.columns)
# Out:
# [**********************88%*****************      ]  7 of 8 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATAMOTORS.NS"}}}
# $TATAMOTORS.NS: possibly delisted; no timezone found
# [*********************100%***********************]  8 of 8 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no timezone found
# Price          Adj Close         Close                                         \
# Ticker     TATAMOTORS.NS BHARTIARTL.NS HDFCBANK.NS HINDUNILVR.NS ICICIBANK.NS
# Date
# 2019-01-01           NaN    280.425446  504.392548   1607.500488   350.957001
# 2019-01-02           NaN    274.413177  499.790222   1592.774048   351.777130
# 2019-01-03           NaN    275.159271  495.868896   1596.165894   350.474609
# 2019-01-04           NaN    283.014679  497.195587   1590.185913   352.356049
# 2019-01-07           NaN    285.208923  497.946899   1593.086548   354.768097
#
# ...

# %%
tickers = ["RELIANCE.NS", "TCS.NS", "HDFCBANK.NS", "INFY.NS", 
           "ICICIBANK.NS", "HINDUNILVR.NS", "BHARTIARTL.NS", "TMPV.NS"]

data = yf.download(tickers, start="2019-01-01", end="2026-06-18")
print(data.head())
print(data.shape)
print(data.columns)
# Out:
# [*********************100%***********************]  8 of 8 completed
# Price              Close                                                     \
# Ticker     BHARTIARTL.NS HDFCBANK.NS HINDUNILVR.NS ICICIBANK.NS     INFY.NS
# Date
# 2019-01-01    280.425446  504.392548   1607.500488   350.957001  541.725708
# 2019-01-02    274.413177  499.790222   1592.774048   351.777130  544.984131
# 2019-01-03    275.159271  495.868896   1596.165894   350.474609  545.065674
# 2019-01-04    283.014679  497.195587   1590.185913   352.356049  538.467651
# 2019-01-07    285.208923  497.946899   1593.086548   354.768097  547.142700
#
# Price                                                    High              \
# Ticker     RELIANCE.NS       TCS.NS     TMPV.NS BHARTIARTL.NS HDFCBANK.NS
# Date
# 2019-01-01  496.196381  1561.000488  170.382263    282.619698  505.073470
# 2019-01-02  489.733887  1577.817871  165.568924    281.741994  504.251587
# ...

# %%
close_prices = data['Close']
print(close_prices.head())
# Out:
# Ticker      BHARTIARTL.NS  HDFCBANK.NS  HINDUNILVR.NS  ICICIBANK.NS  \
# Date
# 2019-01-01     280.425446   504.392548    1607.500488    350.957001
# 2019-01-02     274.413177   499.790222    1592.774048    351.777130
# 2019-01-03     275.159271   495.868896    1596.165894    350.474609
# 2019-01-04     283.014679   497.195587    1590.185913    352.356049
# 2019-01-07     285.208923   497.946899    1593.086548    354.768097
#
# Ticker         INFY.NS  RELIANCE.NS       TCS.NS     TMPV.NS
# Date
# 2019-01-01  541.725708   496.196381  1561.000488  170.382263
# 2019-01-02  544.984131   489.733887  1577.817871  165.568924
# 2019-01-03  545.065674   483.691925  1558.662476  163.113144
# 2019-01-04  538.467651   486.303467  1539.711914  167.926468
# 2019-01-07  547.142700   489.003540  1556.980469  172.248657

# %%
print(data.isnull().sum())
# Out:
# Price   Ticker
# Close   BHARTIARTL.NS    0
#         HDFCBANK.NS      0
#         HINDUNILVR.NS    0
#         ICICIBANK.NS     0
#         INFY.NS          0
#         RELIANCE.NS      0
#         TCS.NS           0
#         TMPV.NS          0
# High    BHARTIARTL.NS    0
#         HDFCBANK.NS      0
#         HINDUNILVR.NS    0
#         ICICIBANK.NS     0
#         INFY.NS          0
#         RELIANCE.NS      0
#         TCS.NS           0
#         TMPV.NS          0
# Low     BHARTIARTL.NS    0
#         HDFCBANK.NS      0
#         HINDUNILVR.NS    0
#         ICICIBANK.NS     0
#         INFY.NS          0
#         RELIANCE.NS      0
#         TCS.NS           0
#         TMPV.NS          0
# Open    BHARTIARTL.NS    0
#         HDFCBANK.NS      0
#         HINDUNILVR.NS    0
#         ICICIBANK.NS     0
#         INFY.NS          0
#         RELIANCE.NS      0
#         TCS.NS           0
#         TMPV.NS          0
# Volume  BHARTIARTL.NS    0
# ...

# %%
import os

# Make sure the data folder exists relative to your notebook
os.makedirs('../data', exist_ok=True)

# Save the full multi-index data
data.to_csv('../data/raw_stock_data.csv')

print("Saved successfully")
print(os.listdir('../data'))
# Out:
# Saved successfully
# ['raw_stock_data.csv']

# %%
git add .
# Out:
#   Cell In[9], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
git add .
git commit -m "Phase 1: data collection setup and raw stock data pull"
git push origin main
# Out:
#   Cell In[10], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %% [raw]
# git add .
# git commit -m "Phase 1: data collection setup and raw stock data pull"
# git push origin main

# %%
git add .
git commit -m "Phase 1: data collection setup and raw stock data pull"
git push origin main
# Out:
#   Cell In[11], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# git add .
# git commit -m "Phase 1: data collection setup and raw stock data pull"
# git push origin main

# %%
git add .
git commit -m "Phase 1: data collection setup and raw stock data pull"
git push origin main
# Out:
#   Cell In[12], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
